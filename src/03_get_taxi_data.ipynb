# %%
import os
from datetime import datetime
from dateutil.relativedelta import relativedelta

import pandas as pd
import requests

# %%
# data request for one trip: 00000019ef3c0b419a9e6b1843b83530b79627a4
url = "https://data.cityofchicago.org/resource/wrvz-psew.json?trip_id=00000019ef3c0b419a9e6b1843b83530b79627a4"

headers = {"X-App-Token" : os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url)

data = response.json()

# %%
response
# Out:
# <Response [200]>

# %%
data
# Out:
# [{'trip_id': '00000019ef3c0b419a9e6b1843b83530b79627a4',
#   'taxi_id': 'bda916a4fa3043f7e827751d9d8cada1239d574beb206d846e1d7d425b658d56aa23393b6866d3a19f9dca6c32d3a8642f14361c5d58dccebd42e398fee18e94',
#   'trip_start_timestamp': '2023-12-11T16:15:00.000',
#   'trip_end_timestamp': '2023-12-11T17:00:00.000',
#   'trip_seconds': '2572',
#   'trip_miles': '17.56',
#   'pickup_census_tract': '17031980000',
#   'dropoff_census_tract': '17031081700',
#   'pickup_community_area': '76',
#   'dropoff_community_area': '8',
#   'fare': '43.75',
#   'tips': '12.06',
#   'tolls': '0',
#   'extras': '4',
#   'trip_total': '60.31',
#   'payment_type': 'Credit Card',
#   'company': 'Taxicab Insurance Agency Llc',
#   'pickup_centroid_latitude': '41.97907082',
#   'pickup_centroid_longitude': '-87.903039661',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.9030396611, 41.9790708201]},
#   'dropoff_centroid_latitude': '41.892042136',
# ...

# %%
# data request for one day: 05-08-2023
url = f"https://data.cityofchicago.org/resource/wrvz-psew.json?$where=trip_start_timestamp >= '2023-08-05T00:00:00' AND trip_start_timestamp <= '2023-08-05T23:59:59'&$limit=30000"

headers = {"X-App-Token" : os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url)

data = response.json()

# %%
# recive a relative date time and formated to right form: current date time - 2 months

current_date_time = datetime.now() - relativedelta(months=2)
formated_datetime = current_date_time.strftime("%Y-%m-%d")

formated_datetime
# Out:
# '2024-10-01'

# %%
#current date time (11-05) - 2 months = 9-05


current_date_time = datetime.now() - relativedelta(months=2)
formated_datetime = current_date_time.strftime("%Y-%m-%d")

url = f"https://data.cityofchicago.org/resource/ajtu-isnz.json?$where=trip_start_timestamp >= '{formated_datetime}T00:00:00' AND trip_start_timestamp <= '{formated_datetime}T23:59:59'&$limit=30000"

headers = {"X-App-Token" : os.environ.get("CHICAGO_API_TOKEN")}

response = requests.get(url)

data = response.json()
data
# Out:
# [{'trip_id': 'c93ebddf36273457b0156092784f88647f78f8f3',
#   'taxi_id': '42560393a9c9b9ae28339f4b5aec77fd89bd49916ad54175d9ee679d69939f973c177065f2816d7990a6663a07270335a4a852190c3258497ba7978edced68c8',
#   'trip_start_timestamp': '2024-10-01T23:45:00.000',
#   'trip_end_timestamp': '2024-10-02T00:00:00.000',
#   'trip_seconds': '1198',
#   'trip_miles': '9.43',
#   'pickup_community_area': '32',
#   'dropoff_community_area': '19',
#   'fare': '25.25',
#   'tips': '6.44',
#   'tolls': '0',
#   'extras': '0',
#   'trip_total': '32.19',
#   'payment_type': 'Credit Card',
#   'company': 'Patriot Taxi Dba Peace Taxi Associat',
#   'pickup_centroid_latitude': '41.878865584',
#   'pickup_centroid_longitude': '-87.625192142',
#   'pickup_centroid_location': {'type': 'Point',
#    'coordinates': [-87.6251921424, 41.8788655841]},
#   'dropoff_centroid_latitude': '41.927260956',
#   'dropoff_centroid_longitude': '-87.765501609',
#   'dropoff_centroid_location': {'type': 'Point',
# ...

# %%
len(data)
# Out:
# 18963

# %%
#2

current_date_time = datetime.now() - relativedelta(months=2)
formated_datetime = current_date_time.strftime("%Y-%m-%d")

url = f'https://data.cityofchicago.org/resource/ajtu-isnz.json?$query=SELECT%0A%20%20%60trip_id%60%2C%0A%20%20%60taxi_id%60%2C%0A%20%20%60trip_start_timestamp%60%2C%0A%20%20%60trip_end_timestamp%60%2C%0A%20%20%60trip_seconds%60%2C%0A%20%20%60trip_miles%60%2C%0A%20%20%60pickup_census_tract%60%2C%0A%20%20%60dropoff_census_tract%60%2C%0A%20%20%60pickup_community_area%60%2C%0A%20%20%60dropoff_community_area%60%2C%0A%20%20%60fare%60%2C%0A%20%20%60tips%60%2C%0A%20%20%60tolls%60%2C%0A%20%20%60extras%60%2C%0A%20%20%60trip_total%60%2C%0A%20%20%60payment_type%60%2C%0A%20%20%60company%60%2C%0A%20%20%60pickup_centroid_latitude%60%2C%0A%20%20%60pickup_centroid_longitude%60%2C%0A%20%20%60pickup_centroid_location%60%2C%0A%20%20%60dropoff_centroid_latitude%60%2C%0A%20%20%60dropoff_centroid_longitude%60%2C%0A%20%20%60dropoff_centroid_location%60%0AWHERE%0A%20%20%60trip_start_timestamp%60%0A%20%20%20%20BETWEEN%20%22{formated_datetime}T00%3A00%3A00%22%20%3A%3A%20floating_timestamp%0A%20%20%20%20AND%20%22{formated_datetime}T23%3A45%3A00%22%20%3A%3A%20floating_timestamp%0AORDER%20BY%20%60trip_start_timestamp%60%20DESC%20NULL%20FIRST'

#headers = {"X-App-Token" : os.environ.get("CHICAGO_API_TOKEN")}

#response = requests.get(url, headers)

data2 = response.json()
len(data2)
# Out:
# 18963
